# %% [markdown]
# # Код для завдання
#
# 1. **Основні типи даних**:

# %%
# Створення змінних з різними типами даних
a = "змінна з текстом"
b = 1  # числова змінна
b1 = 1.1  # числова змінна з плаваючою точкою
c = ["a", 1, 1.25, "Слово", a]  # List
d = {"a": "Слово", "b": 1, a: b}  # Dict
e = ("a", a)  # Tuple
f = {"ss", a + str(b)}  # Set

# Вивід кожної змінної для перевірки
print("Змінна a:", a)
print("Змінна b:", b)
print("Змінна b1:", b1)
print("Список c:", c)
print("Словник d:", d)
print("Кортеж e:", e)
print("Набір f:", f)
# Out:
# Змінна a: змінна з текстом
# Змінна b: 1
# Змінна b1: 1.1
# Список c: ['a', 1, 1.25, 'Слово', 'змінна з текстом']
# Словник d: {'a': 'Слово', 'b': 1, 'змінна з текстом': 1}
# Кортеж e: ('a', 'змінна з текстом')
# Набір f: {'ss', 'змінна з текстом1'}

# %% [markdown]
# 2. **Вбудовані константи та функції**:

# %%
# Вбудовані константи
print("Перша константа:", True)
print(f"Друга константа: {None}")

# Вбудовані функції
print("Абсолютне значення -12.5:", abs(-12.5))
print("Максимальне число з [1, 5, -3, 9]:", max([1, 5, -3, 9]))
print("Результат округлення 3.56:", round(3.56))
# Out:
# Перша константа: True
# Друга константа: None
# Абсолютне значення -12.5: 12.5
# Максимальне число з [1, 5, -3, 9]: 9
# Результат округлення 3.56: 4

# %% [markdown]
# 3. **Цикли**:

# %%
letters = ["a", "b", "c"]
# Цикл for із використанням range
for i in range(len(letters)):
    print(f"На позиції {i} знаходиться буква {letters[i]}")

# Цикл while
count = 0
while count < 3:
    print("Лічильник зараз:", count)
    count += 1
# Out:
# На позиції 0 знаходиться буква a
# На позиції 1 знаходиться буква b
# На позиції 2 знаходиться буква c
# Лічильник зараз: 0
# Лічильник зараз: 1
# Лічильник зараз: 2

# %% [markdown]
# 4. **Розгалуження**:

# %%
A = True
print("Значить A=True" if A else "Значить A=False")

B = 5
if B > 0:
    print("B додатнє")
elif B < 0:
    print("B від'ємне")
else:
    print("B дорівнює нулю")
# Out:
# Значить A=True
# B додатнє

# %% [markdown]
# 5. **Конструкція try-except-finally**:

# %%
A = 0
try:
    print("Що буде якщо", 10 / A, "?")
except ZeroDivisionError as e:
    print("Помилка:", e)
finally:
    print("А от воно що!")
# Out:
# Помилка: division by zero
# А от воно що!

# %% [markdown]
# 6. **Контекст-менеджер with**:

# %%
with open("README.md", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# # Р—РІС–С‚ РґРѕ СЂРѕР±РѕС‚Рё 2
# ## РўРµРјР°: РћСЃРЅРѕРІРё РїСЂРѕРіСЂР°РјСѓРІР°РЅРЅСЏ РЅР° Python
# ### РњРµС‚Р° СЂРѕР±РѕС‚Рё: РћР·РЅР°Р№РѕРјРёС‚РёСЃСЏ Р· РѕСЃРЅРѕРІРЅРёРјРё РєРѕРЅСЃС‚СЂСѓРєС†С–СЏРјРё С‚Р° РјРѕР¶Р»РёРІРѕСЃС‚СЏРјРё Python.
#
# ---
#
# ## Р’РёРєРѕРЅР°РЅРЅСЏ СЂРѕР±РѕС‚Рё
#
# * ### Р РµР·СѓР»СЊС‚Р°С‚Рё РІРёРєРѕРЅР°РЅРЅСЏ Р·Р°РІРґР°РЅСЊ:
# 1. РЎС‚РІРѕСЂРёРІ [С„Р°Р№Р» С–Р· Р±Р°Р·РѕРІРёРјРё РїСЂРёРєР»Р°РґР°РјРё Python-РєРѕРґСѓ](./main.ipynb) РґР»СЏ РѕР·РЅР°Р№РѕРјР»РµРЅРЅСЏ Р· С‚РёРїР°РјРё РґР°РЅРёС… С‚Р° РѕСЃРЅРѕРІРЅРёРјРё РєРѕРЅСЃС‚СЂСѓРєС†С–СЏРјРё;
# 1. РџРѕРїСЂР°С†СЋРІР°РІ С–Р· С†РёРєР»Р°РјРё `for` С– `while`, С‚Р° РЅР°РІС‡РёРІСЃСЏ РІРёРєРѕСЂРёСЃС‚РѕРІСѓРІР°С‚Рё РєРѕРЅСЃС‚СЂСѓРєС†С–С— `if` С‚Р° `try-except`;
# 1. Р’РёРєРѕСЂРёСЃС‚Р°РІ РєРѕРЅС‚РµРєСЃС‚-РјРµРЅРµРґР¶РµСЂ `with` РґР»СЏ СЂРѕР±РѕС‚Рё Р· С„Р°Р№Р»Р°РјРё;
# 1. РЎС‚РІРѕСЂРёРІ [Lambda-С„СѓРЅРєС†С–СЋ](./main.ipynb) С‚Р° РїСЂРѕС‚РµСЃС‚СѓРІР°РІ С—С— РІРёРєРѕРЅР°РЅРЅСЏ. Р РµР·СѓР»СЊС‚Р°С‚ РЅР° СЃРєСЂС–РЅС–:![alt text](image.png)
#
# ---
#
# ## Р’РёСЃРЅРѕРІРѕРє:
#
# - РЈ С†С–Р№ СЂРѕР±РѕС‚С– Р±СѓР»Рё РІРёРєРѕРЅР°РЅС– Р±Р°Р·РѕРІС– РІРїСЂР°РІРё РґР»СЏ РѕР·РЅР°Р№РѕРјР»РµРЅРЅСЏ Р· РєРѕРЅСЃС‚СЂСѓРєС†С–СЏРјРё РјРѕРІРё Python.
# - Р‘СѓР»Рѕ РґРѕСЃСЏРіРЅСѓС‚Рѕ РјРµС‚Сѓ СЂРѕР±РѕС‚Рё: РѕР·РЅР°Р№РѕРјРёС‚РёСЃСЏ Р· РѕСЃРЅРѕРІР°РјРё Python С‚Р° РѕС‚СЂРёРјР°С‚Рё РїСЂР°РєС‚РёС‡РЅРёР№ РґРѕСЃРІС–Рґ СЂРѕР±РѕС‚Рё Р· Р±Р°Р·РѕРІРёРјРё С‚РёРїР°РјРё РґР°РЅРёС…, С†РёРєР»Р°РјРё, СЂРѕР·РіР°Р»СѓР¶РµРЅРЅСЏРјРё, РѕР±СЂРѕР±РєРѕСЋ РїРѕРјРёР»РѕРє С‚Р° РєРѕРЅС‚РµРєСЃС‚-РјРµРЅРµРґР¶РµСЂР°РјРё.
# - РћС‚СЂРёРјР°РЅРѕ Р·РЅР°РЅРЅСЏ РїСЂРѕ СЂС–Р·РЅС– С„СѓРЅРєС†С–С—, РЅР°РїСЂРёРєР»Р°Рґ, СЏРє РІРёРєРѕСЂРёСЃС‚РѕРІСѓРІР°С‚Рё lambda-С„СѓРЅРєС†С–С— С‚Р° РѕР±СЂРѕР±Р»СЏС‚Рё РїРѕРјРёР»РєРё.
# - РџСЂРѕР±Р»РµРј РЅРµ РІРёРЅРёРєР°Р»Рѕ. Р РѕР±РѕС‚Р° РїСЂРёРєРѕР»СЊРЅР°. Р”СЏРєСѓСЋ. рџЄї
#
# ---

# %% [markdown]
# 7. **Lambda-функція**:

# %%
greeting_lambda = lambda first, last: f'Привіт від: {first} {last}'
print("Це просто функція:", greeting_lambda)
print("Це її виклик:", greeting_lambda('Білецької', 'Соломії'))
# Out:
# Це просто функція: <function <lambda> at 0x000002523E076200>
# Це її виклик: Привіт від: Білецької Соломії
